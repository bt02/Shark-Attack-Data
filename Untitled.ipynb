# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_excel('C:/Users/bdtol/Downloads/GSAF5.xls')

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country               Area  \
# 0  2020.10.09  09-Oct-2020  2020.0  Unprovoked  AUSTRALIA  Western Australia
# 1  2020.10.07  07-Oct-2020  2020.0  Unprovoked        USA            Florida
# 2  2020.10.04  04-Oct-2020  2020.0  Unprovoked  AUSTRALIA  Western Australia
# 3  2020.09.21  21-Sep-2020  2020.0         NaN        USA             Hawaii
# 4  2020.09.20  20-Sep-2020  2020.0  Unprovoked        USA            Florida
#
#                                             Location      Activity  \
# 0                          Kelp Beds Beach (Kelpies)       Surfing
# 1                     Miami Beach, Miami-Dade County  Body Surfing
# 2  Toms Surf break, Hamersley Pool, North Beach, ...       Surfing
# 3                          Charley Young Beach, Maui      Swimming
# 4                   Sombero Key Light, Monroe County    Snorkeling
#
#                   Name Sex   Age  \
# 0        Andrew Sharpe    M  NaN
# ...

# %%
df.drop(['href formula', 'href'], axis=1, inplace=True)

# %%
df['Injury'].value_counts()
# Out:
# FATAL                                                                                                                                                                                                                                          823
# Survived                                                                                                                                                                                                                                        97
# Foot bitten                                                                                                                                                                                                                                     93
# No injury                                                                                                                                                                                                                                       84
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25796 entries, 0 to 25795
# Data columns (total 22 columns):
# Case Number               8775 non-null object
# Date                      6579 non-null object
# Year                      6577 non-null float64
# Type                      6569 non-null object
# Country                   6529 non-null object
# Area                      6112 non-null object
# Location                  6029 non-null object
# Activity                  6022 non-null object
# Name                      6364 non-null object
# Sex                       6007 non-null object
# Age                       3675 non-null object
# Injury                    25796 non-null object
# Fatal (Y/N)               6027 non-null object
# Time                      3158 non-null object
# Species                   3625 non-null object
# Investigator or Source    6562 non-null object
# pdf                       6578 non-null object
# Case Number.1             6578 non-null object
# ...

# %%
for i in df['Injury']:
    print(i)
# Out:
# FATAL
# Laceration to lower leg
# No injury, knocked off board when shark grabbed his leg rope
# Lacerations and puncture wounds to shoulder
# Severe bite to shoulder
# Arm bitten by hooked shark PROVOKED INCIDENT
# No injury, board bitten
# Minor cuts and punctures to left foot
# Cuts to right hand and wrist
# Left arm bitten
# Hand bitten that was holding a fish PROVOKED INCIDENT
# FATAL
# Ankle bitten
# Minor injury to forearm
# Shark bit boat, no injury to occupant
# Injury to right foot and ankle
# No injury, kayak damaged
# Minor injury to foot
# Lacerations to sole of left foot
# Minor lacerations to left leg
# Minor injury to arm by a fish
# Lacerations to right calf and posterior thigh
# Injury to left forearm by hooked shark PROVOKED INCIDENT
# Lacerations to hand and wrist
# Lacerations to foot
# Lacerations to foot and toes
# Lacerations to leg
# Lower leg bitten
# No injury to occupants, injury to shark attempting to swallow anchor
# Leg bitten
# FATAL
# ...
